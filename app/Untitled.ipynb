# %%
import pandas as pd

# %%
import json
from pprint import pprint

with open('../Data/Boston/charlesriver.json') as data_file:    
    data = json.load(data_file)

# %%
data.keys()
# Out:
# [u'elements', u'version', u'osm3s', u'generator']

# %%
elements = data['elements']

# %%
for element in elements:
    print(element['type'])
# Out:
# way
# way
# way
# way
# way
# way
# way
# way
# way
# way
# way
# way
# way
# way
# way
# way
# way
# way
# way
# way
# relation
# relation
# relation
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# node
# ...

# %%
if elements[10]['id'] == 160693291:
    print(True)
# Out:
# True
