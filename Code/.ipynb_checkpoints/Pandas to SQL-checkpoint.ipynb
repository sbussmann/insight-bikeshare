# %% [markdown]
# # Transfer pandas dataframe into MySQL database

# %%
import pymysql as mdb
import pandas as pd

# %%
# read in data
df = pd.read_csv('../Data/Boston/BostonFeaturesByStation.csv')

# %%
df
# Out:
#      Unnamed: 0  stationid  duration  nrides  ndays        lat        lng  \
# 0             0          3    713.75    9734    616  42.340021 -71.100812
# 1             1          4    540.00   18058    584  42.345392 -71.069616
# 2             2          5    570.00   10630    587  42.341814 -71.090179
# 3             3          6    630.00   23322    608  42.361285 -71.065140
# 4             4          7    705.00    9163    564  42.353412 -71.044624
# 5             5          8    960.00    7570    617  42.353334 -71.137313
# 6             6          9    720.00   17180    591  42.351313 -71.116174
# 7             7         10    660.00   16159    589  42.350075 -71.105884
# 8             8         11    674.50   12393    619  42.338629 -71.106500
# 9             9         12    589.75   10456    620  42.335911 -71.088496
# 10           10         13    714.00    3798    320  42.334057 -71.074030
# 11           11         14    660.00   15738    623  42.337171 -71.102797
# ...

# %%
df = df.rename(columns={'Unnamed: 0': 'index'})

# %%
# open connection, create database, and write dataframe to table
db = mdb.connect(read_default_file='../Data/Boston/BostonFeatures.cnf')

with db:
    cur = db.cursor()
    cur.execute("CREATE DATABASE IF NOT EXISTS BostonFeaturesByStation_db;")
    #cur.execute("DROP DATABASE BostonFeaturesByStation;")
    cur.execute("USE BostonFeaturesByStation_db;")
    df.to_sql(name = 'BostonFeaturesByStation_tb', con = db, flavor = 'mysql')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-90-2a78c699fc81> in <module>()
#       7     #cur.execute("DROP DATABASE BostonFeaturesByStation;")
#       8     cur.execute("USE BostonFeaturesByStation_db;")
# ----> 9     df.to_sql(name = 'BostonFeaturesByStation_tb', con = db, flavor = 'mysql')
#
# /Users/rbussman/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in to_sql(self, name, con, flavor, schema, if_exists, index, index_label, chunksize, dtype)
#     980             self, name, con, flavor=flavor, schema=schema, if_exists=if_exists,
#     981             index=index, index_label=index_label, chunksize=chunksize,
# --> 982             dtype=dtype)
#     983
#     984     def to_pickle(self, path):
#
# ...
